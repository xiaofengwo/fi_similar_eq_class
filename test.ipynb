# %%
import pandas as pd
import numpy as np
df = pd.read_csv('ch2_train.csv')
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dyn</th>
#       <th>ip</th>
#       <th>eax</th>
#       <th>ecx</th>
#       <th>[i]</th>
#       <th>[a]</th>
#       <th>[b]</th>
#       <th>[sum]</th>
#       <th>[d]</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>20794883</td>
#       <td>3435973836</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>20794887</td>
#       <td>3435973836</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>20794889</td>
#       <td>3435973836</td>
#       <td>0</td>
# ...

# %%
df.fillna(0, inplace=True)
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dyn</th>
#       <th>ip</th>
#       <th>eax</th>
#       <th>ecx</th>
#       <th>[i]</th>
#       <th>[a]</th>
#       <th>[b]</th>
#       <th>[sum]</th>
#       <th>[d]</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>20794883</td>
#       <td>3435973836</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>20794887</td>
#       <td>3435973836</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>20794889</td>
#       <td>3435973836</td>
#       <td>0</td>
# ...

# %%
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dyn</th>
#       <th>ip</th>
#       <th>eax</th>
#       <th>ecx</th>
#       <th>[i]</th>
#       <th>[a]</th>
#       <th>[b]</th>
#       <th>[sum]</th>
#       <th>[d]</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>20794883</td>
#       <td>3.435974e+09</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>20794887</td>
#       <td>3.435974e+09</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>20794889</td>
#       <td>3.435974e+09</td>
# ...

# %%
a = np.random.choice(3,4)
a
pb = 0.5
mask = 0

for i in range (0, 31):
    if np.random.random() < pb:
        mask = (mask | 1) << 1
    else:
        mask = mask << 1
if np.random.random() < pb:
    mask = mask | 1
print(bin(mask))
# Out:
# 0b10100110001001101100010001010100

# %%
import random
VALID_BITS = 32
BOUND_LOW, BOUND_UP = -2**VALID_BITS-1, 2**VALID_BITS - 1
random.randint(BOUND_LOW, BOUND_UP)
# Out:
# -1194904489

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('machine_states.csv')
df2 = pd.read_csv('fi_results.out', sep=' ')

# %%
df1
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dyn</th>
#       <th>ip</th>
#       <th>REG_RDI</th>
#       <th>REG_RSI</th>
#       <th>REG_RBP</th>
#       <th>REG_RSP</th>
#       <th>REG_RBX</th>
#       <th>REG_RDX</th>
#       <th>REG_RCX</th>
#       <th>REG_RAX</th>
#       <th>...</th>
#       <th>index_reg_2</th>
#       <th>scale_2</th>
#       <th>memwrite_addr</th>
#       <th>read_size</th>
#       <th>mem_val</th>
#       <th>displacement</th>
#       <th>base_reg</th>
#       <th>index_reg</th>
#       <th>scale</th>
#       <th>Unnamed: 39</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>4196240</td>
#       <td>2</td>
#       <td>140724770315320</td>
#       <td>4196512</td>
#       <td>140724770315096</td>
#       <td>0</td>
#       <td>140724770315344</td>
#       <td>288</td>
#       <td>4196240</td>
#       <td>...</td>
# ...

# %%
df2
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>num</th>
#       <th>dyn</th>
#       <th>ip</th>
#       <th>reg</th>
#       <th>bit</th>
#       <th>left</th>
#       <th>right</th>
#       <th>result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>4</td>
#       <td>4196255</td>
#       <td>3</td>
#       <td>-2</td>
#       <td>0</td>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>13</td>
#       <td>4196288</td>
#       <td>3</td>
#       <td>-2</td>
#       <td>11</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>16</td>
#       <td>4196299</td>
#       <td>3</td>
#       <td>-2</td>
#       <td>15</td>
#       <td>16</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
# ...

# %%
result = pd.concat([df1, df2], axis=1, join='inner')

# %%
result.shape
# Out:
# (228, 48)

# %%
cols = list(result)
nunique = result.apply(pd.Series.nunique)
cols_to_drop = nunique[nunique == 1].index

# %%
cols_to_drop
# Out:
# Index(['REG_RBX', 'REG_SEG_CS', 'REG_SEG_SS', 'REG_SEG_DS', 'REG_SEG_ES',
#        'REG_SEG_FS', 'REG_SEG_GS', 'index_reg_1', 'memread_addr_2',
#        'read_size_2', 'mem_val_2', 'displacement_2', 'base_reg_2',
#        'index_reg_2', 'scale_2', 'index_reg', 'bit'],
#       dtype='object')

# %%
newresult = result.drop(cols_to_drop, axis=1)
newresult.to_csv('newresult.csv')

# %%
from configuration import Config
x_all = newresult.drop(Config.LABELS, axis=1)
y_all = newresult[:][Config.LABELS]

# %%
x_all.to_csv('x_all.csv')
y_all.to_csv('y_all.csv')

# %%
import numpy as np
mask = np.uint64(0)
one = np.uint64(1)
mask = mask | one

# %%
mask
# Out:
# 1

# %%
a = list(range(0, 100))
import numpy as np
np.random.permutation(100)
# Out:
# array([52, 84, 92, 27, 67, 72, 63,  2, 91, 80,  1, 45,  4, 61, 74, 59, 66,
#        33, 15, 46, 24, 82, 83, 51, 26,  6, 31, 43, 88, 29, 49, 68, 99, 53,
#        65,  7, 23, 75, 47, 85, 18, 98, 64, 41, 17, 11, 13, 34, 62, 10, 19,
#        32, 93, 50, 78, 30, 22,  8, 55, 76, 25, 71, 96, 21, 38, 81, 58, 87,
#        54, 86, 39, 77, 73, 95, 57, 89, 79, 37,  5, 94, 20, 28, 56, 70, 42,
#        36, 35,  0, 40, 48, 44, 97, 60,  3, 14, 16, 69, 12,  9, 90])
